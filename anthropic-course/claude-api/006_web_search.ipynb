# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-3-7-sonnet-latest"

# %%
# Helper functions
from anthropic.types import Message


def add_user_message(messages, message):
    user_message = {
        "role": "user",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)


def add_assistant_message(messages, message):
    assistant_message = {
        "role": "assistant",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[], tools=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join(
        [block.text for block in message.content if block.type == "text"]
    )

web_search_schema = {
    "type": "web_search_20250305",
    "name": "web_search",
    "max_uses": 5
}

# %%
messages = []
add_user_message(
    messages,
    """
    what is the best exercise to do in the morning?
    """,
)
response = chat(messages, tools=[web_search_schema])
response
# Out:
# Message(id='msg_01CToJMeRF56NbArdVTveDt5', content=[TextBlock(citations=None, text="I'd be happy to research the best morning exercises for you. This is a topic where opinions vary, so let me search for some evidence-based information.", type='text'), ServerToolUseBlock(id='srvtoolu_01JdKBNaMJNrBsTEAr5A5E1f', input={'query': 'best exercises to do in the morning benefits research'}, name='web_search', type='server_tool_use'), WebSearchToolResultBlock(content=[WebSearchResultBlock(encrypted_content='...', page_age='1 week ago', title="Early-morning exercise may aid weight loss if you're getting enough sleep | Fox News", type='web_search_result', url='https://www.foxnews.com/health/morning-workouts-can-boost-weight-loss-one-key-habit-followed-experts-say'), WebSearchResultBlock(encrypted_content='...', page_age=None, title='Five Benefits of Exercising in the Morning | Piedmont Healthcare', type='web_search_result', url='https://www.piedmont.org/living-real-change/5-benefits-of-morning-exercise'), WebSearchResultBlock(encrypted_content='...', page_age='July 10, 2019', title='Working Out in the Morning: 13 Benefits, Research, Tips, and More', type='web_search_result', url='https://www.healthline.com/health/exercise-fitness/working-out-in-the-morning'), WebSearchResultBlock(encrypted_content='...', page_age=None, title="Is it better to work out in the morning or at night? Here's what the research says", type='web_search_result', url='https://www.health.com/fitness/morning-workout-benefits'), WebSearchResultBlock(encrypted_content='...', page_age='February 9, 2024', title='Working out in the morning: benefits and 14 tips to get started — Calm Blog', type='web_search_result', url='https://www.calm.com/blog/working-out-in-the-morning'), WebSearchResultBlock(encrypted_content='...', page_age=None, title='Morning and evening exercise - PMC', type='web_search_result', url='https://pmc.ncbi.nlm.nih.gov/articles/PMC5481716/'), WebSearchResultBlock(encrypted_content='...', page_age='June 12, 2024', title="Exercise conundrum: When's the best time to work out?", type='web_search_result', url='https://www.mayoclinichealthsystem.org/hometown-health/speaking-of-health/best-time-of-day-for-your-workout'), WebSearchResultBlock(encrypted_content='...', page_age=None, title='11 Good Morning Exercises To Help You Loosen Up for the Day | Gainful', type='web_search_result', url='https://app.gainful.com/blog/11-good-morning-exercises/'), WebSearchResultBlock(encrypted_content='...', page_age=None, title='Consistent Morning Exercise May Be Beneficial For Individuals with Obesity - PMC', type='web_search_result', url='https://pmc.ncbi.nlm.nih.gov/articles/PMC7492403/'), WebSearchResultBlock(encrypted_content='...', page_age='July 23, 2024', title='Best Time of Day to Workout', type='web_search_result', url='https://health.clevelandclinic.org/does-it-matter-to-your-heart-or-otherwise-what-time-of-day-you-exercise')], tool_use_id='srvtoolu_01JdKBNaMJNrBsTEAr5A5E1f', type='web_search_tool_result'), TextBlock(citations=None, text='Based on the search results, I can provide you with information about the best morning exercises and their benefits.\n\n# Best Exercises to Do in the Morning\n\n## Benefits of Morning Exercise\n\n', type='text'), TextBlock(citations=[CitationsWebSearchResultLocation(cited_text='Morning exercise has been linked to lower obesity risk and improved mental health, but experts emphasize the need to balance workouts with adequate sl...', encrypted_index='Eo8BCioIBRgCIiRiZjA4ODg3OS01MzU5LTQ2ZDAtOWIwMy01YmY4ZmEyYmYwOGESDCdwUULQRmRKUrLKthoMBCttPRoRBUeIg9a3IjAF5yYkjZHNghGD+kR/bpa86lWMiOTv2R8qF767gTfvMpUyz84KmQdn9O3r7kJQ8YsqE7TmCJZeS5IUJAoXWYP0AQiqHP4YBA==', title="Early-morning exercise may aid weight loss if you're getting enough sleep | Fox News", type='web_search_result_location', url='https://www.foxnews.com/health/morning-workouts-can-boost-weight-loss-one-key-habit-followed-experts-say'), CitationsWebSearchResultLocation(cited_text='Exerc ...
